# %% [markdown]
# ## Loading Tensorflow
#
# Before starting this lab, you will need to install [Tensorflow](https://www.tensorflow.org/install/).  If you are using [Google colaboratory](https://colab.research.google.com), Tensorflow is already installed.  Run the following command to ensure Tensorflow is installed.

# %% [markdown]
# # Lab:  Neural Networks for Music Classification
#
# In addition to the concepts in the [MNIST neural network demo](./demo2_mnist_neural.ipynb), in this lab, you will learn to:
# * Load a file from a URL
# * Extract simple features from audio samples for machine learning tasks such as speech recognition and classification
# * Build a simple neural network for music classification using these features
# * Use a callback to store the loss and accuracy history in the training process
# * Optimize the learning rate of the neural network
#
# To illustrate the basic concepts, we will look at a relatively simple music classification problem.  Given a sample of music, we want to determine which instrument (e.g. trumpet, violin, piano) is playing.  This dataset was generously supplied by [Prof. Juan Bello](http://steinhardt.nyu.edu/faculty/Juan_Pablo_Bello) at NYU Stenihardt  and his former PhD student Eric Humphrey (now at Spotify).  They have a complete website dedicated to deep learning methods in music informatics:
#
# http://marl.smusic.nyu.edu/wordpress/projects/feature-learning-deep-architectures/deep-learning-python-tutorial/
#
# You can also check out Juan's <a href="http://www.nyu.edu/classes/bello/ACA.html">course</a>.

# %%
import tensorflow as tf

# %% [markdown]
# Then, load the other packages.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Audio Feature Extraction with Librosa
#
# The key to audio classification is to extract the correct features. In addition to `keras`, we will need the `librosa` package.  The `librosa` package in python has a rich set of methods extracting the features of audio samples commonly used in machine learning tasks such as speech recognition and sound classification.
#
# Installation instructions and complete documentation for the package are given on the [librosa main page](https://librosa.github.io/librosa/).  On most systems, you should be able to simply use:
#
#     pip install librosa
#
# For Unix, you may need to load some additional packages:
#
#     sudo apt-get install build-essential
#     sudo apt-get install libxext-dev python-qt4 qt4-dev-tools
#     pip install librosa
#
# After you have installed the package, try to import it.

# %%
import librosa
import librosa.display
import librosa.feature

# %% [markdown]
# In this lab, we will use a set of music samples from the website:
#
# http://theremin.music.uiowa.edu
#
# This website has a great set of samples for audio processing.  Look on the web for how to use the `requests.get` and `file.write` commands to load the file at the URL provided into your working directory.
#
# You can play the audio sample by copying the file to your local machine and playing it on any media player.  If you listen to it you will hear a soprano saxaphone (with vibrato) playing four notes (C, C#, D, Eb).

# %%
import requests
import os
from tqdm import tqdm

fn = "SopSax.Vib.pp.C6Eb6.aiff"
url = "http://theremin.music.uiowa.edu/sound files/MIS/Woodwinds/sopranosaxophone/"+fn

# TODO:  Load the file from url and save it in a file under the name fn
def download_file(src_url, dst_fn):
    
    if os.path.exists(dst_fn):
        print('File %s already exists' % dst_fn)
        return
    
    print('Downloading %s' % dst_fn)
    
    # Streaming, so we can iterate over the response.
    r = requests.get(src_url, stream=True)

    # Total size in MB.
    total_size = int(r.headers.get('content-length', 0)); 
    block_size = 1024
    wrote = 0 
    with open(dst_fn, 'wb') as f:
        with tqdm(total=total_size//block_size, unit='kB', 
                           unit_scale=True, unit_divisor=1024) as pbar:
            for data in r.iter_content(block_size):
                wrote = wrote + len(data)
                pbar.update(1)
                f.write(data)
    if total_size != 0 and wrote != total_size:
        print("ERROR, something went wrong") 

download_file(url, fn)
# !ls
# Out:
# File SopSax.Vib.pp.C6Eb6.aiff already exists
# drive  sample_data  SopSax.Vib.pp.C6Eb6.aiff

# %% [markdown]
# Next, use `librosa` command `librosa.load` to read the audio file with filename `fn` and get the samples `y` and sample rate `sr`.

# %%
# TODO
# y, sr = ...
y, sr = librosa.load(fn)

# %% [markdown]
# Extracting features from audio files is an entire subject on its own right.  A commonly used set of features are called the Mel Frequency Cepstral Coefficients (MFCCs).  These are derived from the so-called mel spectrogram which is something like a regular spectrogram, but the power and frequency are represented in log scale, which more naturally aligns with human perceptual processing.  You can run the code below to display the mel spectrogram from the audio sample.
#
# You can easily see the four notes played in the audio track.  You also see the 'harmonics' of each notes, which are other tones at integer multiples of the fundamental frequency of each note.

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
librosa.display.specshow(librosa.amplitude_to_db(S),
                         y_axis='mel', fmax=8000, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

# %% [markdown]
# ## Downloading the Data
#
# Using the MFCC features described above, Eric Humphrey and Juan Bellow have created a complete data set that can used for instrument classification.  Essentially, they collected a number of data files from the website above.  For each audio file, the segmented the track into notes and then extracted 120 MFCCs for each note.  The goal is to recognize the instrument from the 120 MFCCs.  The process of feature extraction is quite involved.  So, we will just use their processed data provided at:
#
# https://github.com/marl/dl4mir-tutorial/blob/master/README.md
#
# Note the password.  Load the four files into some directory, say  `instrument_dataset`.  Then, load them with the commands.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# !cd /content/drive/
# !ls /content/drive/My\ Drive/ECE6913
# !tar -xvzf /content/drive/My\ Drive/ECE6913/instrument_dataset.tgz -C /content/drive/My\ Drive/ECE6913/
# !ls /content/drive/My\ Drive/ECE6913/instrument_dataset
# Out:
# /content
# instrument_dataset  instrument_dataset.tgz
# instrument_dataset/
# instrument_dataset/uiowa_test_data.npy
# instrument_dataset/uiowa_test_labels.npy
# instrument_dataset/uiowa_train_data.npy
# instrument_dataset/uiowa_train_labels.npy
# uiowa_test_data.npy    uiowa_train_data.npy
# uiowa_test_labels.npy  uiowa_train_labels.npy

# %%
data_dir = '/content/drive/My Drive/ECE6913/instrument_dataset/'
Xtr = np.load(data_dir+'uiowa_train_data.npy')
ytr = np.load(data_dir+'uiowa_train_labels.npy')
Xts = np.load(data_dir+'uiowa_test_data.npy')
yts = np.load(data_dir+'uiowa_test_labels.npy')

# %% [markdown]
# Looking at the data files:
# * What are the number of training and test samples?
# * What is the number of features for each sample?
# * How many classes (i.e. instruments) are there per class?

# %%
# TODO
print('number of training samples: ', Xtr.shape[0], ' number of test samples: ', Xts.shape[0])
print('number of features =', Xtr.shape[1])
print('number of instruments =', len(set(ytr)))
# Out:
# number of training samples:  66247  number of test samples:  14904
# number of features = 120
# number of instruments = 10

# %% [markdown]
# Before continuing, you must scale the training and test data, `Xtr` and `Xts`.  Compute the mean and std deviation of each feature in `Xtr` and create a new training data set, `Xtr_scale`, by subtracting the mean and dividing by the std deviation.  Also compute a scaled test data set, `Xts_scale` using the mean and std deviation learned from the training data set.

# %%
# TODO Scale the training and test matrices
from sklearn.preprocessing import StandardScaler
scal = StandardScaler()
Xtr_scale = scal.fit_transform(Xtr)
Xts_scale = scal.transform(Xts)

# %% [markdown]
# ## Building a Neural Network Classifier
#
# Following the example in [MNIST neural network demo](./mnist_neural.ipynb), clear the keras session.  Then, create a neural network `model` with:
# * `nh=256` hidden units
# * `sigmoid` activation
# * select the input and output shapes correctly
# * print the model summary

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.backend as K
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-040aef3a775c> in <module>
# ----> 1 from tensorflow.keras.models import Model, Sequential
#       2 from tensorflow.keras.layers import Dense, Activation
#       3 import tensorflow.keras.backend as K
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
# TODO clear session
K.clear_session()

# %%
# TODO: construct the model
nx = 120
nh = 256
nout = 10
model = Sequential()
model.add(Dense(units=nh, input_shape=(nx,), activation='sigmoid', name='hidden'))
model.add(Dense(units=nout, activation='sigmoid', name='output'))

# %%
# TODO:  Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 256)               30976
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 33,546
# Trainable params: 33,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Create an optimizer and compile the model.  Select the appropriate loss function and metrics.  For the optimizer, use the Adam optimizer with a learning rate of 0.001

# %%
# TODO
from tensorflow.keras import optimizers

opt = optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Fit the model for 10 epochs using the scaled data for both the training and validation.  Use the `validation_data` option to pass the test data.  Also, pass the callback class create above.  Use a batch size of 100.  Your final accuracy should be >99%.

# %%
# TODO
hist = model.fit(Xtr_scale, ytr, epochs=10, batch_size=100, validation_data=(Xts_scale,yts))
# Out:
# Epoch 1/10
# 663/663 [==============================] - 2s 3ms/step - loss: 0.3831 - accuracy: 0.8990 - val_loss: 0.1888 - val_accuracy: 0.9398
# Epoch 2/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0941 - accuracy: 0.9781 - val_loss: 0.0851 - val_accuracy: 0.9824
# Epoch 3/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0557 - accuracy: 0.9866 - val_loss: 0.0581 - val_accuracy: 0.9873
# Epoch 4/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0391 - accuracy: 0.9905 - val_loss: 0.0467 - val_accuracy: 0.9871
# Epoch 5/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0299 - accuracy: 0.9923 - val_loss: 0.0398 - val_accuracy: 0.9884
# Epoch 6/10
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.0400 - val_accuracy: 0.9890
# Epoch 7/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.0332 - val_accuracy: 0.9905
# Epoch 8/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0164 - accuracy: 0.9958 - val_loss: 0.0317 - val_accuracy: 0.9895
# Epoch 9/10
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.0305 - val_accuracy: 0.9904
# Epoch 10/10
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.0255 - val_accuracy: 0.9917

# %% [markdown]
# Plot the validation accuracy saved in `hist.history` dictionary. This gives one accuracy value per epoch.  You should see that the validation accuracy saturates at a little higher than 99%.  After that it "bounces around" due to the noise in the stochastic gradient descent.
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \

# %%
# TODO
acc = hist.history['val_accuracy']
plt.plot(acc)
plt.grid()
plt.xlabel('epochs')
plt.ylabel('accuarcy')
# Out:
# Text(0, 0.5, 'accuarcy')

# %% [markdown]
# Plot the loss values saved in the `hist.history` dictionary.  You should see that the loss is steadily decreasing.  Use the `semilogy` plot.

# %%
# TODO
loss = hist.history['loss']
plt.semilogy(loss)
plt.grid()
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## Optimizing the Learning Rate
#
# One challenge in training neural networks is the selection of the learning rate.  Rerun the above code, trying four learning rates as shown in the vector `rates`.  For each learning rate:
# * clear the session
# * construct the network
# * select the optimizer.  Use the Adam optimizer with the appropriate learrning rate.
# * train the model for 20 epochs
# * save the accuracy and losses

# %%
rates = [0.01,0.001,0.0001]
batch_size = 100
loss_hist = []
acc_hist = []

# TODO
# for lr in rate:
#    ...
for lr in rates:
  K.clear_session()
  opt = optimizers.Adam(lr=lr)
  model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  hist = model.fit(Xtr_scale, ytr, epochs=20, batch_size=100, validation_data=(Xts_scale,yts))
  acc_hist.append(hist.history['val_accuracy'])
  loss_hist.append(hist.history['loss'])
# Out:
# Epoch 1/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.1207 - val_accuracy: 0.9804
# Epoch 2/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0378 - val_accuracy: 0.9904
# Epoch 3/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0609 - val_accuracy: 0.9865
# Epoch 4/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0500 - val_accuracy: 0.9883
# Epoch 5/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1875 - val_accuracy: 0.9776
# Epoch 6/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0792 - val_accuracy: 0.9851
# Epoch 7/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0689 - val_accuracy: 0.9890
# Epoch 8/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.1122 - val_accuracy: 0.9837
# Epoch 9/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0651 - val_accuracy: 0.9869
# Epoch 10/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0500 - val_accuracy: 0.9910
# Epoch 11/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0607 - val_accuracy: 0.9880
# Epoch 12/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0657 - val_accuracy: 0.9877
# Epoch 13/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0515 - val_accuracy: 0.9908
# Epoch 14/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0471 - val_accuracy: 0.9887
# Epoch 15/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0977 - val_accuracy: 0.9850
# Epoch 16/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.0670 - val_accuracy: 0.9900
# Epoch 17/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0546 - val_accuracy: 0.9911
# Epoch 18/20
# 663/663 [==============================] - 2s 2ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0512 - val_accuracy: 0.9924
# Epoch 19/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0672 - val_accuracy: 0.9887
# Epoch 20/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0882 - val_accuracy: 0.9868
# Epoch 1/20
# 663/663 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0588 - val_accuracy: 0.9909
# Epoch 2/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.3407e-04 - accuracy: 0.9997 - val_loss: 0.0548 - val_accuracy: 0.9914
# Epoch 3/20
# 663/663 [==============================] - 2s 3ms/step - loss: 3.6264e-04 - accuracy: 0.9998 - val_loss: 0.0561 - val_accuracy: 0.9911
# Epoch 4/20
# 663/663 [==============================] - 2s 2ms/step - loss: 3.0480e-04 - accuracy: 0.9999 - val_loss: 0.0576 - val_accuracy: 0.9915
# Epoch 5/20
# 663/663 [==============================] - 2s 3ms/step - loss: 2.4795e-04 - accuracy: 0.9999 - val_loss: 0.0588 - val_accuracy: 0.9914
# Epoch 6/20
# 663/663 [==============================] - 2s 3ms/step - loss: 2.7779e-04 - accuracy: 0.9999 - val_loss: 0.0603 - val_accuracy: 0.9913
# Epoch 7/20
# 663/663 [==============================] - 2s 3ms/step - loss: 2.6677e-04 - accuracy: 0.9999 - val_loss: 0.0613 - val_accuracy: 0.9916
# Epoch 8/20
# 663/663 [==============================] - 2s 3ms/step - loss: 2.0112e-04 - accuracy: 0.9999 - val_loss: 0.0630 - val_accuracy: 0.9914
# Epoch 9/20
# 663/663 [==============================] - 2s 3ms/step - loss: 2.4845e-04 - accuracy: 0.9999 - val_loss: 0.0624 - val_accuracy: 0.9911
# Epoch 10/20
# 663/663 [==============================] - 2s 3ms/step - loss: 3.0296e-04 - accuracy: 0.9998 - val_loss: 0.0632 - val_accuracy: 0.9915
# Epoch 11/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.7269e-04 - accuracy: 0.9999 - val_loss: 0.0642 - val_accuracy: 0.9910
# Epoch 12/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.6333e-04 - accuracy: 0.9999 - val_loss: 0.0644 - val_accuracy: 0.9909
# Epoch 13/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.3477e-04 - accuracy: 0.9999 - val_loss: 0.0591 - val_accuracy: 0.9914
# Epoch 14/20
# 663/663 [==============================] - 2s 3ms/step - loss: 3.6259e-04 - accuracy: 0.9998 - val_loss: 0.0797 - val_accuracy: 0.9889
# Epoch 15/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.3747e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9903
# Epoch 16/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.3903e-04 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9905
# Epoch 17/20
# 663/663 [==============================] - 2s 2ms/step - loss: 1.4204e-04 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9905
# Epoch 18/20
# 663/663 [==============================] - 2s 2ms/step - loss: 1.3617e-04 - accuracy: 0.9999 - val_loss: 0.0612 - val_accuracy: 0.9909
# Epoch 19/20
# 663/663 [==============================] - 2s 2ms/step - loss: 1.4567e-04 - accuracy: 0.9999 - val_loss: 0.0616 - val_accuracy: 0.9909
# Epoch 20/20
# 663/663 [==============================] - 2s 3ms/step - loss: 3.7807e-04 - accuracy: 0.9998 - val_loss: 0.0635 - val_accuracy: 0.9903
# Epoch 1/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.1972e-04 - accuracy: 0.9999 - val_loss: 0.0629 - val_accuracy: 0.9906
# Epoch 2/20
# 663/663 [==============================] - 2s 3ms/step - loss: 1.1413e-04 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9905
# Epoch 3/20
# 663/663 [==============================] - 2s 3ms/step - loss: 9.7116e-05 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9905
# Epoch 4/20
# 663/663 [==============================] - 2s 2ms/step - loss: 8.6816e-05 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9905
# Epoch 5/20
# 663/663 [==============================] - 2s 3ms/step - loss: 7.9532e-05 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9905
# Epoch 6/20
# 663/663 [==============================] - 2s 3ms/step - loss: 7.5655e-05 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9905
# Epoch 7/20
# 663/663 [==============================] - 2s 3ms/step - loss: 7.3669e-05 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9905
# Epoch 8/20
# 663/663 [==============================] - 2s 2ms/step - loss: 7.1545e-05 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9905
# Epoch 9/20
# 663/663 [==============================] - 2s 3ms/step - loss: 7.1347e-05 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9904
# Epoch 10/20
# 663/663 [==============================] - 2s 2ms/step - loss: 6.9955e-05 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9904
# Epoch 11/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.9497e-05 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9903
# Epoch 12/20
# 663/663 [==============================] - 2s 2ms/step - loss: 6.7963e-05 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9903
# Epoch 13/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.8089e-05 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9903
# Epoch 14/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.6856e-05 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9903
# Epoch 15/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.6904e-05 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9903
# Epoch 16/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.6462e-05 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9902
# Epoch 17/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.6003e-05 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9902
# Epoch 18/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.5088e-05 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9903
# Epoch 19/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.4691e-05 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9902
# Epoch 20/20
# 663/663 [==============================] - 2s 3ms/step - loss: 6.5134e-05 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9902

# %% [markdown]
# Plot the loss funciton vs. the epoch number for all three learning rates on one graph.  You should see that the lower learning rates are more stable, but converge slower.
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \\

# %%
# TODO
plt.semilogy(loss_hist[0])
plt.semilogy(loss_hist[1])
plt.semilogy(loss_hist[2])
plt.grid()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['lr = 0.01', 'lr = 0.001', 'lr = 0.0001'])

# %%
plt.plot(acc_hist[0])
plt.plot(acc_hist[1])
plt.plot(acc_hist[2])
plt.grid()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['lr = 0.01', 'lr = 0.001', 'lr = 0.0001'])
