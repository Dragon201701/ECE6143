# %% [markdown]
#  # Lab:  Transfer Learning with a Pre-Trained Deep Neural Network
#
# As we discussed earlier, state-of-the-art neural networks involve millions of parameters that are prohibitively difficult to train from scratch.  In this lab, we will illustrate a powerful technique called *fine-tuning* where we start with a large pre-trained network and then re-train only the final layers to adapt to a new task.  The method is also called *transfer learning* and can produce excellent results on very small datasets with very little computational time.
#
# This lab is based partially on this
# [excellent blog](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).  In performing the lab, you will learn to:
# * Build a custom image dataset
# * Fine tune the final layers of an existing deep neural network for a new classification task.
# * Load images with a `DataGenerator`.
#
# The lab has two versions:
# * *CPU version*:  In this version, you use lower resolution images so that the lab can be performed on your laptop.  The resulting accuracy is lower.  The code will also take considerable time to execute.
# * *GPU version*:  This version uses higher resolution images but requires a GPU instance. See the [notes](../GCP/getting_started.md) on setting up a GPU instance on Google Cloud Platform.  The GPU training is much faster (< 1 minute).
#
# **MS students must complete the GPU version** of this lab.

# %% [markdown]
# ## Create a Dataset
#
# In this example, we will try to develop a classifier that can discriminate between two classes:  `cars` and `bicycles`.  One could imagine this type of classifier would be useful in vehicle vision systems.   The first task is to build a dataset.
#
# TODO:  Create training and test datasets with:
# * 1000 training images of cars
# * 1000 training images of bicylces
# * 300 test images of cars
# * 300 test images of bicylces
# * The images don't need to be the same size.  But, you can reduce the resolution if you need to save disk space.
#
# The images should be organized in the following directory structure:
#
#     ./train
#         /car
#            car_0000.jpg
#            car_0001.jpg
#            ...
#            car_0999.jpg
#         /bicycle
#            bicycle_0000.jpg
#            bicycle_0001.jpg
#            ...
#            bicycle_0999.jpg
#     ./test
#         /car
#            car_1001.jpg
#            car_1001.jpg
#            ...
#            car_1299.jpg
#         /bicycle
#            bicycle_1000.jpg
#            bicycle_1001.jpg
#            ...
#            bicycle_1299.jpg
#
# The naming of the files within the directories does not matter.  The `ImageDataGenerator` class below will find the filenames.  Just make sure there are the correct number of files in each directory.
#
# A nice automated way of building such a dataset if through the [FlickrAPI](demo2_flickr_images.ipynb).  Remember that if you run the FlickrAPI twice, it may collect the same images.  So, you need to run it once and split the images into training and test directories.

# %%
import flickrapi
import urllib.request
import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import skimage.transform
import requests
from io import BytesIO
import os
# %matplotlib inline
api_key = u'aaac807741d42c36ccf9062c3847f00b'
api_secret = u'fed3c3180ae604f8'
flickr = flickrapi.FlickrAPI(api_key, api_secret)

# %%
keyword1 = 'car'
keyword2 = 'bicycle'

photos_car = flickr.walk(text=keyword1, tag_mode='all', tags=keyword1,extras='url_c',\
                     sort='relevance',per_page=100)
photos_bicycle = flickr.walk(text=keyword2, tag_mode='all', tags=keyword2,extras='url_c',\
                     sort='relevance',per_page=100)

# %%
import warnings
def downloadsplitandsave(photos, keyword, nimage_train, nimage_test, nrow, ncol):
    # Download from flickr, number them and save the training samples to 
    # ./train/keyword and test samples to 
    # ./test/keyword.
    dir_name_tr = './train/' + keyword
    dir_name_ts = './test/' + keyword
    if not os.path.isdir('./train'):
        os.mkdir('./train')
        print("Making new folder: " + './train')
    if not os.path.isdir('./test/'):
        os.mkdir('./test/')
        print("Making new folder: " + './test/')
    if not os.path.isdir(dir_name_tr):
        os.mkdir(dir_name_tr)
        print("Making new folder: " + dir_name_tr)
    if not os.path.isdir(dir_name_ts):
        os.mkdir(dir_name_ts)
        print("Making new folder: " + dir_name_ts)
    i = 0
    nimage = nimage_train + nimage_test
    for photo in photos:
        url=photo.get('url_c')
        if not (url is None):
            
            # Create a file from the URL
            # This may only work in Python3
            response = requests.get(url)
            file = BytesIO(response.content)
            
            # Read image from file
            im = skimage.io.imread(file)
            
            # Resize images
            im1 = skimage.transform.resize(im,(nrow,ncol),mode='constant')
                    
            # Convert to uint8, suppress the warning about the precision loss
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                im2 = skimage.img_as_ubyte(im1)
            # Save image
            if i < nimage_train:
                local_name = '{0:s}/{1:s}_{2:04d}.jpg'.format(dir_name_tr,keyword, i)
            else:
                local_name = '{0:s}/{1:s}_{2:04d}.jpg'.format(dir_name_ts,keyword, i)
            skimage.io.imsave(local_name, im2)
            print("Saving: ", local_name)
            i = i + 1
        if i >= nimage:
            break

# %%
nimage_tr = 1000
nimage_ts = 300
nrow = 224
ncol = 224

downloadsplitandsave(photos_car, keyword1, nimage_tr, nimage_ts, nrow, ncol)
downloadsplitandsave(photos_bicycle, keyword2, nimage_tr, nimage_ts, nrow, ncol)
# Out:
# ycle_0816.jpg
# Saving:  ./train/bicycle/bicycle_0817.jpg
# Saving:  ./train/bicycle/bicycle_0818.jpg
# Saving:  ./train/bicycle/bicycle_0819.jpg
# Saving:  ./train/bicycle/bicycle_0820.jpg
# Saving:  ./train/bicycle/bicycle_0821.jpg
# Saving:  ./train/bicycle/bicycle_0822.jpg
# Saving:  ./train/bicycle/bicycle_0823.jpg
# Saving:  ./train/bicycle/bicycle_0824.jpg
# Saving:  ./train/bicycle/bicycle_0825.jpg
# Saving:  ./train/bicycle/bicycle_0826.jpg
# Saving:  ./train/bicycle/bicycle_0827.jpg
# Saving:  ./train/bicycle/bicycle_0828.jpg
# Saving:  ./train/bicycle/bicycle_0829.jpg
# Saving:  ./train/bicycle/bicycle_0830.jpg
# Saving:  ./train/bicycle/bicycle_0831.jpg
# Saving:  ./train/bicycle/bicycle_0832.jpg
# Saving:  ./train/bicycle/bicycle_0833.jpg
# Saving:  ./train/bicycle/bicycle_0834.jpg
# Saving:  ./train/bicycle/bicycle_0835.jpg
# Saving:  ./train/bicycle/bicycle_0836.jpg
# Saving:  ./train/bicycle/bicycle_0837.jpg
# Saving:  ./train/bicycle/bicycle_0838.jpg
# Saving:  ./train/bicycle/bicycle_0839.jpg
# Saving:  ./train/bicycle/bicycle_0840.jpg
# Saving:  ./train/bicycle/bicycle_0841.jpg
# Saving:  ./train/bicycle/bicycle_0842.jpg
# Saving:  ./train/bicycle/bicycle_0843.jpg
# Saving:  ./train/bicycle/bicycle_0844.jpg
# Saving:  ./train/bicycle/bicycle_0845.jpg
# Saving:  ./train/bicycle/bicycle_0846.jpg
# Saving:  ./train/bicycle/bicycle_0847.jpg
# Saving:  ./train/bicycle/bicycle_0848.jpg
# Saving:  ./train/bicycle/bicycle_0849.jpg
# Saving:  ./train/bicycle/bicycle_0850.jpg
# Saving:  ./train/bicycle/bicycle_0851.jpg
# Saving:  ./train/bicycle/bicycle_0852.jpg
# Saving:  ./train/bicycle/bicycle_0853.jpg
# Saving:  ./train/bicycle/bicycle_0854.jpg
# Saving:  ./train/bicycle/bicycle_0855.jpg
# Saving:  ./train/bicycle/bicycle_0856.jpg
# Saving:  ./train/bicycle/bicycle_0857.jpg
# Saving:  ./train/bicycle/bicycle_0858.jpg
# Saving:  ./train/bicycle/bicycle_0859.jpg
# Saving:  ./train/bicycle/bicycle_0860.jpg
# Saving:  ./train/bicycle/bicycle_0861.jpg
# Saving:  ./train/bicycle/bicycle_0862.jpg
# Saving:  ./train/bicycle/bicycle_0863.jpg
# Saving:  ./train/bicycle/bicycle_0864.jpg
# Saving:  ./train/bicycle/bicycle_0865.jpg
# Saving:  ./train/bicycle/bicycle_0866.jpg
# Saving:  ./train/bicycle/bicycle_0867.jpg
# Saving:  ./train/bicycle/bicycle_0868.jpg
# Saving:  ./train/bicycle/bicycle_0869.jpg
# Saving:  ./train/bicycle/bicycle_0870.jpg
# Saving:  ./train/bicycle/bicycle_0871.jpg
# Saving:  ./train/bicycle/bicycle_0872.jpg
# Saving:  ./train/bicycle/bicycle_0873.jpg
# Saving:  ./train/bicycle/bicycle_0874.jpg
# Saving:  ./train/bicycle/bicycle_0875.jpg
# Saving:  ./train/bicycle/bicycle_0876.jpg
# Saving:  ./train/bicycle/bicycle_0877.jpg
# Saving:  ./train/bicycle/bicycle_0878.jpg
# Saving:  ./train/bicycle/bicycle_0879.jpg
# Saving:  ./train/bicycle/bicycle_0880.jpg
# Saving:  ./train/bicycle/bicycle_0881.jpg
# Saving:  ./train/bicycle/bicycle_0882.jpg
# Saving:  ./train/bicycle/bicycle_0883.jpg
# Saving:  ./train/bicycle/bicycle_0884.jpg
# Saving:  ./train/bicycle/bicycle_0885.jpg
# Saving:  ./train/bicycle/bicycle_0886.jpg
# Saving:  ./train/bicycle/bicycle_0887.jpg
# Saving:  ./train/bicycle/bicycle_0888.jpg
# Saving:  ./train/bicycle/bicycle_0889.jpg
# Saving:  ./train/bicycle/bicycle_0890.jpg
# Saving:  ./train/bicycle/bicycle_0891.jpg
# Saving:  ./train/bicycle/bicycle_0892.jpg
# Saving:  ./train/bicycle/bicycle_0893.jpg
# Saving:  ./train/bicycle/bicycle_0894.jpg
# Saving:  ./train/bicycle/bicycle_0895.jpg
# Saving:  ./train/bicycle/bicycle_0896.jpg
# Saving:  ./train/bicycle/bicycle_0897.jpg
# Saving:  ./train/bicycle/bicycle_0898.jpg
# Saving:  ./train/bicycle/bicycle_0899.jpg
# Saving:  ./train/bicycle/bicycle_0900.jpg
# Saving:  ./train/bicycle/bicycle_0901.jpg
# Saving:  ./train/bicycle/bicycle_0902.jpg
# Saving:  ./train/bicycle/bicycle_0903.jpg
# Saving:  ./train/bicycle/bicycle_0904.jpg
# Saving:  ./train/bicycle/bicycle_0905.jpg
# Saving:  ./train/bicycle/bicycle_0906.jpg
# Saving:  ./train/bicycle/bicycle_0907.jpg
# Saving:  ./train/bicycle/bicycle_0908.jpg
# Saving:  ./train/bicycle/bicycle_0909.jpg
# Saving:  ./train/bicycle/bicycle_0910.jpg
# Saving:  ./train/bicycle/bicycle_0911.jpg
# Saving:  ./train/bicycle/bicycle_0912.jpg
# Saving:  ./train/bicycle/bicycle_0913.jpg
# Saving:  ./train/bicycle/bicycle_0914.jpg
# Saving:  ./train/bicycle/bicycle_0915.jpg
# Saving:  ./train/bicycle/bicycle_0916.jpg
# Saving:  ./train/bicycle/bicycle_0917.jpg
# Saving:  ./train/bicycle/bicycle_0918.jpg
# Saving:  ./train/bicycle/bicycle_0919.jpg
# Saving:  ./train/bicycle/bicycle_0920.jpg
# Saving:  ./train/bicycle/bicycle_0921.jpg
# Saving:  ./train/bicycle/bicycle_0922.jpg
# Saving:  ./train/bicycle/bicycle_0923.jpg
# Saving:  ./train/bicycle/bicycle_0924.jpg
# Saving:  ./train/bicycle/bicycle_0925.jpg
# Saving:  ./train/bicycle/bicycle_0926.jpg
# Saving:  ./train/bicycle/bicycle_0927.jpg
# Saving:  ./train/bicycle/bicycle_0928.jpg
# Saving:  ./train/bicycle/bicycle_0929.jpg
# Saving:  ./train/bicycle/bicycle_0930.jpg
# Saving:  ./train/bicycle/bicycle_0931.jpg
# Saving:  ./train/bicycle/bicycle_0932.jpg
# Saving:  ./train/bicycle/bicycle_0933.jpg
# Saving:  ./train/bicycle/bicycle_0934.jpg
# Saving:  ./train/bicycle/bicycle_0935.jpg
# Saving:  ./train/bicycle/bicycle_0936.jpg
# Saving:  ./train/bicycle/bicycle_0937.jpg
# Saving:  ./train/bicycle/bicycle_0938.jpg
# Saving:  ./train/bicycle/bicycle_0939.jpg
# Saving:  ./train/bicycle/bicycle_0940.jpg
# Saving:  ./train/bicycle/bicycle_0941.jpg
# Saving:  ./train/bicycle/bicycle_0942.jpg
# Saving:  ./train/bicycle/bicycle_0943.jpg
# Saving:  ./train/bicycle/bicycle_0944.jpg
# Saving:  ./train/bicycle/bicycle_0945.jpg
# Saving:  ./train/bicycle/bicycle_0946.jpg
# Saving:  ./train/bicycle/bicycle_0947.jpg
# Saving:  ./train/bicycle/bicycle_0948.jpg
# Saving:  ./train/bicycle/bicycle_0949.jpg
# Saving:  ./train/bicycle/bicycle_0950.jpg
# Saving:  ./train/bicycle/bicycle_0951.jpg
# Saving:  ./train/bicycle/bicycle_0952.jpg
# Saving:  ./train/bicycle/bicycle_0953.jpg
# Saving:  ./train/bicycle/bicycle_0954.jpg
# Saving:  ./train/bicycle/bicycle_0955.jpg
# Saving:  ./train/bicycle/bicycle_0956.jpg
# Saving:  ./train/bicycle/bicycle_0957.jpg
# Saving:  ./train/bicycle/bicycle_0958.jpg
# Saving:  ./train/bicycle/bicycle_0959.jpg
# Saving:  ./train/bicycle/bicycle_0960.jpg
# Saving:  ./train/bicycle/bicycle_0961.jpg
# Saving:  ./train/bicycle/bicycle_0962.jpg
# Saving:  ./train/bicycle/bicycle_0963.jpg
# Saving:  ./train/bicycle/bicycle_0964.jpg
# Saving:  ./train/bicycle/bicycle_0965.jpg
# Saving:  ./train/bicycle/bicycle_0966.jpg
# Saving:  ./train/bicycle/bicycle_0967.jpg
# Saving:  ./train/bicycle/bicycle_0968.jpg
# Saving:  ./train/bicycle/bicycle_0969.jpg
# Saving:  ./train/bicycle/bicycle_0970.jpg
# Saving:  ./train/bicycle/bicycle_0971.jpg
# Saving:  ./train/bicycle/bicycle_0972.jpg
# Saving:  ./train/bicycle/bicycle_0973.jpg
# Saving:  ./train/bicycle/bicycle_0974.jpg
# Saving:  ./train/bicycle/bicycle_0975.jpg
# Saving:  ./train/bicycle/bicycle_0976.jpg
# Saving:  ./train/bicycle/bicycle_0977.jpg
# Saving:  ./train/bicycle/bicycle_0978.jpg
# Saving:  ./train/bicycle/bicycle_0979.jpg
# Saving:  ./train/bicycle/bicycle_0980.jpg
# Saving:  ./train/bicycle/bicycle_0981.jpg
# Saving:  ./train/bicycle/bicycle_0982.jpg
# Saving:  ./train/bicycle/bicycle_0983.jpg
# Saving:  ./train/bicycle/bicycle_0984.jpg
# Saving:  ./train/bicycle/bicycle_0985.jpg
# Saving:  ./train/bicycle/bicycle_0986.jpg
# Saving:  ./train/bicycle/bicycle_0987.jpg
# Saving:  ./train/bicycle/bicycle_0988.jpg
# Saving:  ./train/bicycle/bicycle_0989.jpg
# Saving:  ./train/bicycle/bicycle_0990.jpg
# Saving:  ./train/bicycle/bicycle_0991.jpg
# Saving:  ./train/bicycle/bicycle_0992.jpg
# Saving:  ./train/bicycle/bicycle_0993.jpg
# Saving:  ./train/bicycle/bicycle_0994.jpg
# Saving:  ./train/bicycle/bicycle_0995.jpg
# Saving:  ./train/bicycle/bicycle_0996.jpg
# Saving:  ./train/bicycle/bicycle_0997.jpg
# Saving:  ./train/bicycle/bicycle_0998.jpg
# Saving:  ./train/bicycle/bicycle_0999.jpg
# Saving:  ./test/bicycle/bicycle_1000.jpg
# Saving:  ./test/bicycle/bicycle_1001.jpg
# Saving:  ./test/bicycle/bicycle_1002.jpg
# Saving:  ./test/bicycle/bicycle_1003.jpg
# Saving:  ./test/bicycle/bicycle_1004.jpg
# Saving:  ./test/bicycle/bicycle_1005.jpg
# Saving:  ./test/bicycle/bicycle_1006.jpg
# Saving:  ./test/bicycle/bicycle_1007.jpg
# Saving:  ./test/bicycle/bicycle_1008.jpg
# Saving:  ./test/bicycle/bicycle_1009.jpg
# Saving:  ./test/bicycle/bicycle_1010.jpg
# Saving:  ./test/bicycle/bicycle_1011.jpg
# Saving:  ./test/bicycle/bicycle_1012.jpg
# Saving:  ./test/bicycle/bicycle_1013.jpg
# Saving:  ./test/bicycle/bicycle_1014.jpg
# Saving:  ./test/bicycle/bicycle_1015.jpg
# Saving:  ./test/bicycle/bicycle_1016.jpg
# Saving:  ./test/bicycle/bicycle_1017.jpg
# Saving:  ./test/bicycle/bicycle_1018.jpg
# Saving:  ./test/bicycle/bicycle_1019.jpg
# Saving:  ./test/bicycle/bicycle_1020.jpg
# Saving:  ./test/bicycle/bicycle_1021.jpg
# Saving:  ./test/bicycle/bicycle_1022.jpg
# Saving:  ./test/bicycle/bicycle_1023.jpg
# Saving:  ./test/bicycle/bicycle_1024.jpg
# Saving:  ./test/bicycle/bicycle_1025.jpg
# Saving:  ./test/bicycle/bicycle_1026.jpg
# Saving:  ./test/bicycle/bicycle_1027.jpg
# Saving:  ./test/bicycle/bicycle_1028.jpg
# Saving:  ./test/bicycle/bicycle_1029.jpg
# Saving:  ./test/bicycle/bicycle_1030.jpg
# Saving:  ./test/bicycle/bicycle_1031.jpg
# Saving:  ./test/bicycle/bicycle_1032.jpg
# Saving:  ./test/bicycle/bicycle_1033.jpg
# Saving:  ./test/bicycle/bicycle_1034.jpg
# Saving:  ./test/bicycle/bicycle_1035.jpg
# Saving:  ./test/bicycle/bicycle_1036.jpg
# Saving:  ./test/bicycle/bicycle_1037.jpg
# Saving:  ./test/bicycle/bicycle_1038.jpg
# Saving:  ./test/bicycle/bicycle_1039.jpg
# Saving:  ./test/bicycle/bicycle_1040.jpg
# Saving:  ./test/bicycle/bicycle_1041.jpg
# Saving:  ./test/bicycle/bicycle_1042.jpg
# Saving:  ./test/bicycle/bicycle_1043.jpg
# Saving:  ./test/bicycle/bicycle_1044.jpg
# Saving:  ./test/bicycle/bicycle_1045.jpg
# Saving:  ./test/bicycle/bicycle_1046.jpg
# Saving:  ./test/bicycle/bicycle_1047.jpg
# Saving:  ./test/bicycle/bicycle_1048.jpg
# Saving:  ./test/bicycle/bicycle_1049.jpg
# Saving:  ./test/bicycle/bicycle_1050.jpg
# Saving:  ./test/bicycle/bicycle_1051.jpg
# Saving:  ./test/bicycle/bicycle_1052.jpg
# Saving:  ./test/bicycle/bicycle_1053.jpg
# Saving:  ./test/bicycle/bicycle_1054.jpg
# Saving:  ./test/bicycle/bicycle_1055.jpg
# Saving:  ./test/bicycle/bicycle_1056.jpg
# Saving:  ./test/bicycle/bicycle_1057.jpg
# Saving:  ./test/bicycle/bicycle_1058.jpg
# Saving:  ./test/bicycle/bicycle_1059.jpg
# Saving:  ./test/bicycle/bicycle_1060.jpg
# Saving:  ./test/bicycle/bicycle_1061.jpg
# Saving:  ./test/bicycle/bicycle_1062.jpg
# Saving:  ./test/bicycle/bicycle_1063.jpg
# Saving:  ./test/bicycle/bicycle_1064.jpg
# Saving:  ./test/bicycle/bicycle_1065.jpg
# Saving:  ./test/bicycle/bicycle_1066.jpg
# Saving:  ./test/bicycle/bicycle_1067.jpg
# Saving:  ./test/bicycle/bicycle_1068.jpg
# Saving:  ./test/bicycle/bicycle_1069.jpg
# Saving:  ./test/bicycle/bicycle_1070.jpg
# Saving:  ./test/bicycle/bicycle_1071.jpg
# Saving:  ./test/bicycle/bicycle_1072.jpg
# Saving:  ./test/bicycle/bicycle_1073.jpg
# Saving:  ./test/bicycle/bicycle_1074.jpg
# Saving:  ./test/bicycle/bicycle_1075.jpg
# Saving:  ./test/bicycle/bicycle_1076.jpg
# Saving:  ./test/bicycle/bicycle_1077.jpg
# Saving:  ./test/bicycle/bicycle_1078.jpg
# Saving:  ./test/bicycle/bicycle_1079.jpg
# Saving:  ./test/bicycle/bicycle_1080.jpg
# Saving:  ./test/bicycle/bicycle_1081.jpg
# Saving:  ./test/bicycle/bicycle_1082.jpg
# Saving:  ./test/bicycle/bicycle_1083.jpg
# Saving:  ./test/bicycle/bicycle_1084.jpg
# Saving:  ./test/bicycle/bicycle_1085.jpg
# Saving:  ./test/bicycle/bicycle_1086.jpg
# Saving:  ./test/bicycle/bicycle_1087.jpg
# Saving:  ./test/bicycle/bicycle_1088.jpg
# Saving:  ./test/bicycle/bicycle_1089.jpg
# Saving:  ./test/bicycle/bicycle_1090.jpg
# Saving:  ./test/bicycle/bicycle_1091.jpg
# Saving:  ./test/bicycle/bicycle_1092.jpg
# Saving:  ./test/bicycle/bicycle_1093.jpg
# Saving:  ./test/bicycle/bicycle_1094.jpg
# Saving:  ./test/bicycle/bicycle_1095.jpg
# Saving:  ./test/bicycle/bicycle_1096.jpg
# Saving:  ./test/bicycle/bicycle_1097.jpg
# Saving:  ./test/bicycle/bicycle_1098.jpg
# Saving:  ./test/bicycle/bicycle_1099.jpg
# Saving:  ./test/bicycle/bicycle_1100.jpg
# Saving:  ./test/bicycle/bicycle_1101.jpg
# Saving:  ./test/bicycle/bicycle_1102.jpg
# Saving:  ./test/bicycle/bicycle_1103.jpg
# Saving:  ./test/bicycle/bicycle_1104.jpg
# Saving:  ./test/bicycle/bicycle_1105.jpg
# Saving:  ./test/bicycle/bicycle_1106.jpg
# Saving:  ./test/bicycle/bicycle_1107.jpg
# Saving:  ./test/bicycle/bicycle_1108.jpg
# Saving:  ./test/bicycle/bicycle_1109.jpg
# Saving:  ./test/bicycle/bicycle_1110.jpg
# Saving:  ./test/bicycle/bicycle_1111.jpg
# Saving:  ./test/bicycle/bicycle_1112.jpg
# Saving:  ./test/bicycle/bicycle_1113.jpg
# Saving:  ./test/bicycle/bicycle_1114.jpg
# Saving:  ./test/bicycle/bicycle_1115.jpg
# Saving:  ./test/bicycle/bicycle_1116.jpg
# Saving:  ./test/bicycle/bicycle_1117.jpg
# Saving:  ./test/bicycle/bicycle_1118.jpg
# Saving:  ./test/bicycle/bicycle_1119.jpg
# Saving:  ./test/bicycle/bicycle_1120.jpg
# Saving:  ./test/bicycle/bicycle_1121.jpg
# Saving:  ./test/bicycle/bicycle_1122.jpg
# Saving:  ./test/bicycle/bicycle_1123.jpg
# Saving:  ./test/bicycle/bicycle_1124.jpg
# Saving:  ./test/bicycle/bicycle_1125.jpg
# Saving:  ./test/bicycle/bicycle_1126.jpg
# Saving:  ./test/bicycle/bicycle_1127.jpg
# Saving:  ./test/bicycle/bicycle_1128.jpg
# Saving:  ./test/bicycle/bicycle_1129.jpg
# Saving:  ./test/bicycle/bicycle_1130.jpg
# Saving:  ./test/bicycle/bicycle_1131.jpg
# Saving:  ./test/bicycle/bicycle_1132.jpg
# Saving:  ./test/bicycle/bicycle_1133.jpg
# Saving:  ./test/bicycle/bicycle_1134.jpg
# Saving:  ./test/bicycle/bicycle_1135.jpg
# Saving:  ./test/bicycle/bicycle_1136.jpg
# Saving:  ./test/bicycle/bicycle_1137.jpg
# Saving:  ./test/bicycle/bicycle_1138.jpg
# Saving:  ./test/bicycle/bicycle_1139.jpg
# Saving:  ./test/bicycle/bicycle_1140.jpg
# Saving:  ./test/bicycle/bicycle_1141.jpg
# Saving:  ./test/bicycle/bicycle_1142.jpg
# Saving:  ./test/bicycle/bicycle_1143.jpg
# Saving:  ./test/bicycle/bicycle_1144.jpg
# Saving:  ./test/bicycle/bicycle_1145.jpg
# Saving:  ./test/bicycle/bicycle_1146.jpg
# Saving:  ./test/bicycle/bicycle_1147.jpg
# Saving:  ./test/bicycle/bicycle_1148.jpg
# Saving:  ./test/bicycle/bicycle_1149.jpg
# Saving:  ./test/bicycle/bicycle_1150.jpg
# Saving:  ./test/bicycle/bicycle_1151.jpg
# Saving:  ./test/bicycle/bicycle_1152.jpg
# Saving:  ./test/bicycle/bicycle_1153.jpg
# Saving:  ./test/bicycle/bicycle_1154.jpg
# Saving:  ./test/bicycle/bicycle_1155.jpg
# Saving:  ./test/bicycle/bicycle_1156.jpg
# Saving:  ./test/bicycle/bicycle_1157.jpg
# Saving:  ./test/bicycle/bicycle_1158.jpg
# Saving:  ./test/bicycle/bicycle_1159.jpg
# Saving:  ./test/bicycle/bicycle_1160.jpg
# Saving:  ./test/bicycle/bicycle_1161.jpg
# Saving:  ./test/bicycle/bicycle_1162.jpg
# Saving:  ./test/bicycle/bicycle_1163.jpg
# Saving:  ./test/bicycle/bicycle_1164.jpg
# Saving:  ./test/bicycle/bicycle_1165.jpg
# Saving:  ./test/bicycle/bicycle_1166.jpg
# Saving:  ./test/bicycle/bicycle_1167.jpg
# Saving:  ./test/bicycle/bicycle_1168.jpg
# Saving:  ./test/bicycle/bicycle_1169.jpg
# Saving:  ./test/bicycle/bicycle_1170.jpg
# Saving:  ./test/bicycle/bicycle_1171.jpg
# Saving:  ./test/bicycle/bicycle_1172.jpg
# Saving:  ./test/bicycle/bicycle_1173.jpg
# Saving:  ./test/bicycle/bicycle_1174.jpg
# Saving:  ./test/bicycle/bicycle_1175.jpg
# Saving:  ./test/bicycle/bicycle_1176.jpg
# Saving:  ./test/bicycle/bicycle_1177.jpg
# Saving:  ./test/bicycle/bicycle_1178.jpg
# Saving:  ./test/bicycle/bicycle_1179.jpg
# Saving:  ./test/bicycle/bicycle_1180.jpg
# Saving:  ./test/bicycle/bicycle_1181.jpg
# Saving:  ./test/bicycle/bicycle_1182.jpg
# Saving:  ./test/bicycle/bicycle_1183.jpg
# Saving:  ./test/bicycle/bicycle_1184.jpg
# Saving:  ./test/bicycle/bicycle_1185.jpg
# Saving:  ./test/bicycle/bicycle_1186.jpg
# Saving:  ./test/bicycle/bicycle_1187.jpg
# Saving:  ./test/bicycle/bicycle_1188.jpg
# Saving:  ./test/bicycle/bicycle_1189.jpg
# Saving:  ./test/bicycle/bicycle_1190.jpg
# Saving:  ./test/bicycle/bicycle_1191.jpg
# Saving:  ./test/bicycle/bicycle_1192.jpg
# Saving:  ./test/bicycle/bicycle_1193.jpg
# Saving:  ./test/bicycle/bicycle_1194.jpg
# Saving:  ./test/bicycle/bicycle_1195.jpg
# Saving:  ./test/bicycle/bicycle_1196.jpg
# Saving:  ./test/bicycle/bicycle_1197.jpg
# Saving:  ./test/bicycle/bicycle_1198.jpg
# Saving:  ./test/bicycle/bicycle_1199.jpg
# Saving:  ./test/bicycle/bicycle_1200.jpg
# Saving:  ./test/bicycle/bicycle_1201.jpg
# Saving:  ./test/bicycle/bicycle_1202.jpg
# Saving:  ./test/bicycle/bicycle_1203.jpg
# Saving:  ./test/bicycle/bicycle_1204.jpg
# Saving:  ./test/bicycle/bicycle_1205.jpg
# Saving:  ./test/bicycle/bicycle_1206.jpg
# Saving:  ./test/bicycle/bicycle_1207.jpg
# Saving:  ./test/bicycle/bicycle_1208.jpg
# Saving:  ./test/bicycle/bicycle_1209.jpg
# Saving:  ./test/bicycle/bicycle_1210.jpg
# Saving:  ./test/bicycle/bicycle_1211.jpg
# Saving:  ./test/bicycle/bicycle_1212.jpg
# Saving:  ./test/bicycle/bicycle_1213.jpg
# Saving:  ./test/bicycle/bicycle_1214.jpg
# Saving:  ./test/bicycle/bicycle_1215.jpg
# Saving:  ./test/bicycle/bicycle_1216.jpg
# Saving:  ./test/bicycle/bicycle_1217.jpg
# Saving:  ./test/bicycle/bicycle_1218.jpg
# Saving:  ./test/bicycle/bicycle_1219.jpg
# Saving:  ./test/bicycle/bicycle_1220.jpg
# Saving:  ./test/bicycle/bicycle_1221.jpg
# Saving:  ./test/bicycle/bicycle_1222.jpg
# Saving:  ./test/bicycle/bicycle_1223.jpg
# Saving:  ./test/bicycle/bicycle_1224.jpg
# Saving:  ./test/bicycle/bicycle_1225.jpg
# Saving:  ./test/bicycle/bicycle_1226.jpg
# Saving:  ./test/bicycle/bicycle_1227.jpg
# Saving:  ./test/bicycle/bicycle_1228.jpg
# Saving:  ./test/bicycle/bicycle_1229.jpg
# Saving:  ./test/bicycle/bicycle_1230.jpg
# Saving:  ./test/bicycle/bicycle_1231.jpg
# Saving:  ./test/bicycle/bicycle_1232.jpg
# Saving:  ./test/bicycle/bicycle_1233.jpg
# Saving:  ./test/bicycle/bicycle_1234.jpg
# Saving:  ./test/bicycle/bicycle_1235.jpg
# Saving:  ./test/bicycle/bicycle_1236.jpg
# Saving:  ./test/bicycle/bicycle_1237.jpg
# Saving:  ./test/bicycle/bicycle_1238.jpg
# Saving:  ./test/bicycle/bicycle_1239.jpg
# Saving:  ./test/bicycle/bicycle_1240.jpg
# Saving:  ./test/bicycle/bicycle_1241.jpg
# Saving:  ./test/bicycle/bicycle_1242.jpg
# Saving:  ./test/bicycle/bicycle_1243.jpg
# Saving:  ./test/bicycle/bicycle_1244.jpg
# Saving:  ./test/bicycle/bicycle_1245.jpg
# Saving:  ./test/bicycle/bicycle_1246.jpg
# Saving:  ./test/bicycle/bicycle_1247.jpg
# Saving:  ./test/bicycle/bicycle_1248.jpg
# Saving:  ./test/bicycle/bicycle_1249.jpg
# Saving:  ./test/bicycle/bicycle_1250.jpg
# Saving:  ./test/bicycle/bicycle_1251.jpg
# Saving:  ./test/bicycle/bicycle_1252.jpg
# Saving:  ./test/bicycle/bicycle_1253.jpg
# Saving:  ./test/bicycle/bicycle_1254.jpg
# Saving:  ./test/bicycle/bicycle_1255.jpg
# Saving:  ./test/bicycle/bicycle_1256.jpg
# Saving:  ./test/bicycle/bicycle_1257.jpg
# Saving:  ./test/bicycle/bicycle_1258.jpg
# Saving:  ./test/bicycle/bicycle_1259.jpg
# Saving:  ./test/bicycle/bicycle_1260.jpg
# Saving:  ./test/bicycle/bicycle_1261.jpg
# Saving:  ./test/bicycle/bicycle_1262.jpg
# Saving:  ./test/bicycle/bicycle_1263.jpg
# Saving:  ./test/bicycle/bicycle_1264.jpg
# Saving:  ./test/bicycle/bicycle_1265.jpg
# Saving:  ./test/bicycle/bicycle_1266.jpg
# Saving:  ./test/bicycle/bicycle_1267.jpg
# Saving:  ./test/bicycle/bicycle_1268.jpg
# Saving:  ./test/bicycle/bicycle_1269.jpg
# Saving:  ./test/bicycle/bicycle_1270.jpg
# Saving:  ./test/bicycle/bicycle_1271.jpg
# Saving:  ./test/bicycle/bicycle_1272.jpg
# Saving:  ./test/bicycle/bicycle_1273.jpg
# Saving:  ./test/bicycle/bicycle_1274.jpg
# Saving:  ./test/bicycle/bicycle_1275.jpg
# Saving:  ./test/bicycle/bicycle_1276.jpg
# Saving:  ./test/bicycle/bicycle_1277.jpg
# Saving:  ./test/bicycle/bicycle_1278.jpg
# Saving:  ./test/bicycle/bicycle_1279.jpg
# Saving:  ./test/bicycle/bicycle_1280.jpg
# Saving:  ./test/bicycle/bicycle_1281.jpg
# Saving:  ./test/bicycle/bicycle_1282.jpg
# Saving:  ./test/bicycle/bicycle_1283.jpg
# Saving:  ./test/bicycle/bicycle_1284.jpg
# Saving:  ./test/bicycle/bicycle_1285.jpg
# Saving:  ./test/bicycle/bicycle_1286.jpg
# Saving:  ./test/bicycle/bicycle_1287.jpg
# Saving:  ./test/bicycle/bicycle_1288.jpg
# Saving:  ./test/bicycle/bicycle_1289.jpg
# Saving:  ./test/bicycle/bicycle_1290.jpg
# Saving:  ./test/bicycle/bicycle_1291.jpg
# Saving:  ./test/bicycle/bicycle_1292.jpg
# Saving:  ./test/bicycle/bicycle_1293.jpg
# Saving:  ./test/bicycle/bicycle_1294.jpg
# Saving:  ./test/bicycle/bicycle_1295.jpg
# Saving:  ./test/bicycle/bicycle_1296.jpg
# Saving:  ./test/bicycle/bicycle_1297.jpg
# Saving:  ./test/bicycle/bicycle_1298.jpg
# Saving:  ./test/bicycle/bicycle_1299.jpg

# %% [markdown]
# ## Loading a Pre-Trained Deep Network
#
# We follow the [VGG16 demo](./demo3_vgg16.ipynb) to load a pre-trained deep VGG16 network.  First, run a command to verify your instance is connected to a GPU.

# %%
# TODO
# !SET PATH=C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v10.1\bin;%PATH%
# !SET PATH=C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v10.1\extras\CUPTI\lib64;%PATH%
# !SET PATH=C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v10.1\include;%PATH%
from tensorflow.python.client import device_lib
import tensorflow as tf
print(device_lib.list_local_devices())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8092937647900667327
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13886416300697308336
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6579684390
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8645538758527399590
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17807588600750935772
# physical_device_desc: "device: XLA_GPU device"
# ]
# Num GPUs Available:  1

# %%
from scipy import misc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import decode_predictions, preprocess_input

# %% [markdown]
# Now load the appropriate tensorflow packages.

# %%
from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense

# %% [markdown]
# We also load some standard packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Clear the Keras session.

# %%
# TODO
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.backend as K
K.clear_session()

# %% [markdown]
# Set the dimensions of the input image.  The sizes below would work on a GPU machine.  But, if you have a CPU image, you can use a smaller image size, like `64 x 64`.

# %%
# TODO:  Set to smaller values if you are using a CPU.  
# Otherwise, do not change this code.
nrow = 150
ncol = 150

# %% [markdown]
# Now we follow the [VGG16 demo](./vgg16.ipynb) and load the deep VGG16 network.  Alternatively, you can use any other pre-trained model in keras.  When using the `applications.VGG16` method you will need to:
# * Set `include_top=False` to not include the top layer
# * Set the `image_shape` based on the above dimensions.  Remember, `image_shape` should be `height x width x 3` since the images are color.

# %%
# TODO:  Load the VGG16 network
input_shape = (nrow, ncol, 3)
base_model = applications.VGG16(weights='imagenet', input_shape=input_shape, include_top=False)

# %% [markdown]
# To create now new model, we create a Sequential model.  Then, loop over the layers in `base_model.layers` and add each layer to the new model.

# %%
# Create a new model
model = Sequential()

# TODO:  Loop over base_model.layers and add each layer to model
for layer in base_model.layers:
    model.add(layer)

# %% [markdown]
# Next, loop through the layers in `model`, and freeze each layer by setting `layer.trainable = False`.  This way, you will not have to *re-train* any of the existing layers.

# %%
# TODO
for layer in model.layers:
    layer.trainable = False

# %% [markdown]
# Now, add the following layers to `model`:
# * A `Flatten()` layer which reshapes the outputs to a single channel.
# * A fully-connected layer with 256 output units and `relu` activation
# * A `Dropout(0.5)` layer.
# * A final fully-connected layer.  Since this is a binary classification, there should be one output and `sigmoid` activation.

# %%
# TODO
model.add(Flatten())
model.add(Dense(units=256, activation='relu', name='hidden'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid', name='output'))

# %% [markdown]
# Print the model summary.  This will display the number of trainable parameters vs. the non-trainable parameters.

# %%
# TODO
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# hidden (Dense)               (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Using Generators to Load Data
#
# Up to now, the training data has been represented in a large matrix.  This is not possible for image data when the datasets are very large.  For these applications, the `keras` package provides a `ImageDataGenerator` class that can fetch images on the fly from a directory of images.  Using multi-threading, training can be performed on one mini-batch while the image reader can read files for the next mini-batch. The code below creates an `ImageDataGenerator` for the training data.  In addition to the reading the files, the `ImageDataGenerator` creates random deformations of the image to expand the total dataset size.  When the training data is limited, using data augmentation is very important.

# %%
train_data_dir = './train'
batch_size = 32
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
train_generator = train_datagen.flow_from_directory(
                        train_data_dir,
                        target_size=(nrow,ncol),
                        batch_size=batch_size,
                        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# Now, create a similar `test_generator` for the test data.

# %%
# TODO
test_data_dir = './test'
batch_size = 32
test_generator = train_datagen.flow_from_directory(
                        test_data_dir,
                        target_size=(nrow,ncol),
                        batch_size=batch_size,
                        class_mode='binary')
# Out:
# Found 600 images belonging to 2 classes.

# %% [markdown]
# The following function displays images that will be useful below.

# %%
# Display the image
def disp_image(im, tag=None):
    if (len(im.shape) == 2):
        # Gray scale image
        plt.imshow(im, cmap='gray')    
    else:
        # Color image.  
        im1 = (im-np.min(im))/(np.max(im)-np.min(im))*255
        im1 = im1.astype(np.uint8)
        plt.imshow(im1)    
    if tag != None:
        plt.title('%d' % tag)
    # Remove axis ticks
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# To see how the `train_generator` works, use the `train_generator.next()` method to get a minibatch of data `X,y`.  Display the first 8 images in this mini-batch and label the image with the class label.  You should see that bicycles have `y=0` and cars have `y=1`.

# %%
# TODO
X,y = train_generator.next()
for i in range(0, 8):
    plt.subplot(1, 8, i+1)
    disp_image(X[i], y[i])

# %% [markdown]
# ## Train the Model
#
# Compile the model.  Select the correct `loss` function, `optimizer` and `metrics`.  Remember that we are performing binary classification.

# %%
# TODO.
from tensorflow.keras import optimizers

opt = optimizers.Adam(lr=0.01)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# When using an `ImageDataGenerator`, we have to set two parameters manually:
# * `steps_per_epoch =  training data size // batch_size`
# * `validation_steps =  test data size // batch_size`
#
# We can obtain the training and test data size from `train_generator.n` and `test_generator.n`, respectively.

# %%
# TODO
steps_per_epoch = train_generator.n/batch_size
validation_steps = test_generator.n/batch_size

# %% [markdown]
# Now, we run the fit.  If you are using a CPU on a regular laptop, each epoch will take about 3-4 minutes, so you should be able to finish 5 epochs or so within 20 minutes.  On a reasonable GPU, even with the larger images, it will take about 10 seconds per epoch.
# * If you use `(nrow,ncol) = (64,64)` images, you should get around 90% accuracy after 5 epochs.
# * If you use `(nrow,ncol) = (150,150)` images, you should get around 96% accuracy after 5 epochs.  But, this will need a GPU.
#
# You will get full credit for either version.  With more epochs, you may get slightly higher, but you will have to play with the damping.
#
# Remember to record the history of the fit, so that you can plot the training and validation accuracy curve.

# %%
nepochs = 10  # Number of epochs

# Call the fit_generator function
hist = model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=nepochs,
    validation_data=test_generator,
    validation_steps=validation_steps)
# Out:
# WARNING:tensorflow:From <ipython-input-21-950ca0d665e8>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 63/62 [==============================] - 51s 802ms/step - loss: 1.4444 - accuracy: 0.8745 - val_loss: 0.1535 - val_accuracy: 0.9550
# Epoch 2/10
# 63/62 [==============================] - 11s 177ms/step - loss: 0.0820 - accuracy: 0.9715 - val_loss: 0.0937 - val_accuracy: 0.9750
# Epoch 3/10
# 63/62 [==============================] - 11s 178ms/step - loss: 0.0715 - accuracy: 0.9765 - val_loss: 0.1169 - val_accuracy: 0.9683
# Epoch 4/10
# 63/62 [==============================] - 11s 180ms/step - loss: 0.0516 - accuracy: 0.9815 - val_loss: 0.1346 - val_accuracy: 0.9650
# Epoch 5/10
# 63/62 [==============================] - 12s 193ms/step - loss: 0.0454 - accuracy: 0.9805 - val_loss: 0.1522 - val_accuracy: 0.9667
# Epoch 6/10
# 63/62 [==============================] - 12s 183ms/step - loss: 0.0641 - accuracy: 0.9780 - val_loss: 0.1320 - val_accuracy: 0.9650
# Epoch 7/10
# 63/62 [==============================] - 11s 181ms/step - loss: 0.0375 - accuracy: 0.9840 - val_loss: 0.1316 - val_accuracy: 0.9667
# Epoch 8/10
# 63/62 [==============================] - 11s 179ms/step - loss: 0.0491 - accuracy: 0.9790 - val_loss: 0.1228 - val_accuracy: 0.9650
# Epoch 9/10
# 63/62 [==============================] - 12s 184ms/step - loss: 0.0648 - accuracy: 0.9745 - val_loss: 0.1102 - val_accuracy: 0.9683
# Epoch 10/10
# 63/62 [==============================] - 11s 182ms/step - loss: 0.0526 - accuracy: 0.9840 - val_loss: 0.0922 - val_accuracy: 0.9683

# %%
# Plot the training accuracy and validation accuracy curves on the same figure.
tr_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

plt.plot(tr_accuracy)
plt.plot(val_accuracy)
plt.grid()
plt.xlabel('epochs')
plt.ylabel('accuarcy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# ## Plotting the Error Images
#
# Now try to plot some images that were in error:
#
# *  Generate a mini-batch `Xts,yts` from the `test_generator.next()` method
# *  Get the class probabilities using the `model.predict( )` method and compute predicted labels `yhat`.
# *  Get the images where `yts[i] ~= yhat[i]`.
# *  If you did not get any prediction error in one minibatch, run it multiple times.
# *  After you a get a few error images (say 4-8), plot the error images with the true labels and class probabilities predicted by the classifie

# %%
# TO DO
Xerr = []
yerr = []
while len(yerr) <= 6:
    Xts, yts = test_generator.next()
    yhat = np.rint(model.predict(Xts))
    for i in range(0, len(yts)):
        if yts[i] != yhat[i]:
            print("yts: ", yts[i], " yhat: ", yhat[i])
            Xerr.append(Xts[i])
            yerr.append(yts[i])
for i in range(0, len(yerr)):
    plt.subplot(1, len(yerr), i+1)
    disp_image(Xerr[i], yerr[i])
# Out:
# yts:  0.0  yhat:  [1.]
# yts:  0.0  yhat:  [1.]
# yts:  0.0  yhat:  [1.]
